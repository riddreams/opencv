# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
cat = cv2.imread('cat.jpg')
# bgr 转换为 rgb
#cat = cv2.cvtColor(cat,cv2.COLOR_BGR2RGB)
plt.imshow(cat)
plt.show()

# %%
print(cat)
px = cat[100,100]
print('cat在[100,100]处的[b g r]:')
print(px)
print('cat在[100,100]处的blue分量:')
blue = cat[100,100,0]
print(blue)
# Out:
# [[[ 13  85  55]
#   [ 40 104  75]
#   [ 48 105  80]
#   ...
#   [ 35 101  76]
#   [ 28 135  96]
#   [  2 132  85]]
#
#  [[ 15  85  55]
#   [ 28  93  67]
#   [ 92 153 127]
#   ...
#   [ 22  83  57]
#   [ 30 114  80]
#   [ 37 138 100]]
#
#  [[  2  68  39]
#   [ 14  81  54]
#   [ 45 112  85]
#   ...
#   [ 24  79  52]
#   [ 78 138 108]
#   [ 43 111  80]]
#
#  ...
#
#  [[ 80 100 105]
#   [ 72  92  97]
#   [ 54  73  78]
#   ...
#   [181 235 188]
#   [169 228 177]
#   [142 205 149]]
#
#  [[ 69  91  97]
#   [ 80 102 107]
#   [ 67  89  94]
#   ...
#   [153 202 158]
#   [132 188 137]
#   [162 222 168]]
#
#  [[ 73  95 101]
#   [ 73  95 100]
#   [ 76  99 101]
#   ...
#   [139 185 142]
#   [120 176 125]
#   [130 188 134]]]
# cat在[100,100]处的[b g r]:
# [173 203 238]
# cat在[100,100]处的blue分量:
# 173

# %%
print(cat.shape)
print(cat.size)
print(cat.dtype)
# Out:
# (276, 276, 3)
# 228528
# uint8

# %%
head = cat[70:150,70:150]
cat[70:150,160:240] = head
plt.imshow(cat)
plt.show()

# %%
b = cat[:,:,0]
g = cat[:,:,1]
r = cat[:,:,2]
print('blue:')
print(b)
print('green:')
print(g)
print('red:')
print(r)
# Out:
# blue:
# [[ 13  40  48 ...  35  28   2]
#  [ 15  28  92 ...  22  30  37]
#  [  2  14  45 ...  24  78  43]
#  ...
#  [ 80  72  54 ... 181 169 142]
#  [ 69  80  67 ... 153 132 162]
#  [ 73  73  76 ... 139 120 130]]
# green:
# [[ 85 104 105 ... 101 135 132]
#  [ 85  93 153 ...  83 114 138]
#  [ 68  81 112 ...  79 138 111]
#  ...
#  [100  92  73 ... 235 228 205]
#  [ 91 102  89 ... 202 188 222]
#  [ 95  95  99 ... 185 176 188]]
# red:
# [[ 55  75  80 ...  76  96  85]
#  [ 55  67 127 ...  57  80 100]
#  [ 39  54  85 ...  52 108  80]
#  ...
#  [105  97  78 ... 188 177 149]
#  [ 97 107  94 ... 158 137 168]
#  [101 100 101 ... 142 125 134]]

# %%
img = cv2.copyMakeBorder(cat,20,20,20,20,cv2.BORDER_REPLICATE)
plt.imshow(img)
plt.show()
